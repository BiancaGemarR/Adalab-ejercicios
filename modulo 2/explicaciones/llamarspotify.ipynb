# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
CLIENT_ID = "fd65ba2c42ec4fa281add322068595c1"
CLIENT_SECRET = "834a625cc8514033b535125485177f82"

# %%
# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'
results = sp.artist_albums(birdy_uri, album_type='album')

# %%
print(results)
# Out:
# {'href': 'https://api.spotify.com/v1/artists/2WX2uTcsvV5OnS0inACecP/albums?offset=0&limit=20&include_groups=album', 'limit': 20, 'next': None, 'offset': 0, 'previous': None, 'total': 10, 'items': [{'album_type': 'album', 'total_tracks': 15, 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML
# ...

# %%
http GET https://api.spotify.com/v1/tracks/fd65ba2c42ec4fa281add322068595c1 \
  Authorization:'Bearer 1POdFZRZbvb...qqillRxMr2z'
# Out:
#   Cell In[7], line 1
#     http GET https://api.spotify.com/v1/tracks/fd65ba2c42ec4fa281add322068595c1 \
#          ^
# SyntaxError: invalid syntax

# %%
datos = sp.search(q= 'genre:classical, year:2020', type = 'track', limit= 50, offset=0)

# %%
datos.keys()
# Out:
# dict_keys(['tracks'])

# %%
datos['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zWsPzrwV38onHR0yjq1w5'},
#     'href': 'https://api.spotify.com/v1/artists/4zWsPzrwV38onHR0yjq1w5',
#     'id': '4zWsPzrwV38onHR0yjq1w5',
#     'name': 'Albert Guinovart',
#     'type': 'artist',
#     'uri': 'spotify:artist:4zWsPzrwV38onHR0yjq1w5'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0PcQNxT17Cg56orvaIeckF'},
#     'href': 'https://api.spotify.com/v1/artists/0PcQNxT17Cg56orvaIeckF',
#     'id': '0PcQNxT17Cg56orvaIeckF',
#     'name': 'Diego Martín-Etxebarria',
#     'type': 'artist',
#     'uri': 'spotify:artist:0PcQNxT17Cg56orvaIeckF'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0ktP4DZorNKIZt2MoKImCj'},
#     'href': 'https://api.spotify.com/v1/artists/0ktP4DZorNKIZt2MoKImCj',
#     'id': '0ktP4DZorNKIZt2MoKImCj',
#     'name': 'Orquestra Simfónica de Barcelona i Nacional de Catalunya (OBC)',
# ...

# %%
datos['tracks']['items'][0]['name'] #nom del track

# %%
for i in range(0,500,50):
    print(i)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450

# %%
for q in range(2016,2021):
    print(q)
# Out:
# 2016
# 2017
# 2018
# 2019
# 2020

# %%
for i in range(0,500,50):
    for a in range(2016,2021):
        datos = sp.search(q= 'genre : classical, year: 2025', type = 'track', limit= 50, offset=i)
# Out:
#   Cell In[62], line 3
#     datos = sp.search(q= 'genre : classical', 'year: 2025', type = 'track', limit= 50, offset=i)
#                                                                                                ^
# SyntaxError: positional argument follows keyword argument

# %%
datos = sp.search(q= 'genre : classical, year: 2025', type = 'track', limit= 50, offset=i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 datos = sp.search(q= 'genre : classical, year: 2025', type = 'track', limit= 50, offset=i)
#
# NameError: name 'i' is not defined

# %%
print(datos)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=450&limit=50&query=genre%20%3A%20classical%2C%20year%3A%202025&type=track', 'limit': 50, 'next': 'https://api.spotify.com/v1/search?offset=500&limit=50&query=genre%20%3A%20classical%2C%20year%3A%202025&type=track', 'offset': 450, 'previous': 'https://api.spotify.com/v1/search?offset=400&limit=50&query=genre%20%3A%20classical%2C%20year%3A%202025&type=track', 'total': 1000, 'items': [{'album': {'album_type': 'compilation', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'}, 'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of', 'id': '0LyfQWJT6nXafLPZqxe9Of', 'name': 'Various Artists', 'type': 'artist', 'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/24mUgIQY2KZLbDCrdfqCnT'}, 'href': 'https://api.spotify.com/v1/artists/24mUgIQY2KZLbDCrdfqCnT', 'id': '24mUgIQY2KZLbDCrdfqCnT', 'name': 'Enrique García A
# ...

# %%
datos.keys()
# Out:
# dict_keys(['tracks'])

# %%
datos['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/24mUgIQY2KZLbDCrdfqCnT'},
#     'href': 'https://api.spotify.com/v1/artists/24mUgIQY2KZLbDCrdfqCnT',
#     'id': '24mUgIQY2KZLbDCrdfqCnT',
#     'name': 'Enrique García Asensio',
#     'type': 'artist',
#     'uri': 'spotify:artist:24mUgIQY2KZLbDCrdfqCnT'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5fxihNvDF3pcvedj725kmi'},
#     'href': 'https://api.spotify.com/v1/artists/5fxihNvDF3pcvedj725kmi',
#     'id': '5fxihNvDF3pcvedj725kmi',
#     'name': 'Miquel Ortega',
#     'type': 'artist',
# ...

# %%
datos['tracks']['items'][0]['name']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 datos['tracks']['items'][0]['name']
#
# NameError: name 'datos' is not defined

# %%
print(datos['tracks']['items'][1]['name'])
print(datos['tracks']['items'][1]['type'])
# Out:
# Mellow Moments
# track

# %%
datos['tracks']['items'][1].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
datos['tracks']['items'][1]['album']
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zkggbMTw8FFPrXuZ0SVm6'},
#    'href': 'https://api.spotify.com/v1/artists/4zkggbMTw8FFPrXuZ0SVm6',
#    'id': '4zkggbMTw8FFPrXuZ0SVm6',
#    'name': 'Aginws',
#    'type': 'artist',
#    'uri': 'spotify:artist:4zkggbMTw8FFPrXuZ0SVm6'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
# ...

# %%
datos['tracks']['items'][1]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4zkggbMTw8FFPrXuZ0SVm6'},
#   'href': 'https://api.spotify.com/v1/artists/4zkggbMTw8FFPrXuZ0SVm6',
#   'id': '4zkggbMTw8FFPrXuZ0SVm6',
#   'name': 'Aginws',
#   'type': 'artist',
#   'uri': 'spotify:artist:4zkggbMTw8FFPrXuZ0SVm6'}]

# %%
datos['tracks']['items'][1]['artists'][1]['artists'] #nombre del artista
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 datos['tracks']['items'][1]['artists'][1]['artists']
#
# IndexError: list index out of range

# %%
datos['tracks']['items'][1]['album']['name'] #nombre del album
# Out:
# 'Gentlez'

# %%
datos['tracks']['items'][12]['album']['release_date'] #fecha de lanzamiento
# Out:
# '2020-11-13'
