# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
CLIENT_ID = "fd65ba2c42ec4fa281add322068595c1"
CLIENT_SECRET = "834a625cc8514033b535125485177f82"

# %%
# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
datos['tracks']['items'][0]['name'] #nom del track

# %%
for i in range(0,500,50):
    print(i)

# %%
for year in range(2016,2021):
    print(q)

# %%
#crear función

#genre = 'classical'
#year = '2025' 
def llamada(genre, year):
    datos = sp.search(q= f'genre:{genre}, year:{year}', type='track', limit=50, offset=0) #poner format
    for item in datos['tracks']['items']: 
        release_date = item['album']['release_date']
        if release_date.startswith(str(year)): #la api de spotify no filtra el año en la query, 
                                             #se necesita poner startswith para que en la fecha empieze por 2025 que es el año que queremos buscar
            print(item['artists'][0]['name']) #nombre artista
            print(item['album']['name']) #nombre del album
            print(item['album']['release_date']) #fecha de lanzamiento
            print(item['type']) #tipo 
            print(item['name']) #nom del track
            print('..........')

# %%
llamada('classical', '2022')
# Out:
# Albert Guinovart
# Carneriana
# 2022-03-11
# track
# Els somnis: Somni No. 3
# ..........
# Wolfgang Amadeus Mozart
# Mozart For Relaxation
# 2022-02-18
# track
# Piano Concerto No. 16 in D Major, K. 451: Ii. Andante
# ..........
# Henry Smith
# Covers Piano 2022
# 2022-11-26
# track
# She Will Be Loved - Piano Version
# ..........
# Francisco Tárrega
# Spanish Guitar Music
# 2022-11-24
# track
# Capricho Árabe
# ..........
# Henry Smith
# Covers Piano 2022
# 2022-11-26
# track
# Because You Loved Me - Piano Version
# ..........
# Francisco Tárrega
# Spanish Guitar Music
# 2022-11-24
# track
# Endecha Oremus
# ..........
# Johann Sebastian Bach
# J.S. Bach: The Art of Fugue, BWV 1080
# 2022-02-25
# track
# The Art of Fugue, BWV 1080: Canon per augmentationem in contrario motu
# ..........
# Wolfgang Amadeus Mozart
# Mozart For Relaxation
# 2022-02-18
# track
# Sinfonia Concertante in E-flat Major, K. 364: Ii. Andante
# ..........
# Henry Smith
# Covers Piano 2022
# 2022-11-26
# ...
