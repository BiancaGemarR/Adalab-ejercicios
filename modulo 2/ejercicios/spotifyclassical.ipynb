# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
CLIENT_ID = "fd65ba2c42ec4fa281add322068595c1"
CLIENT_SECRET = "834a625cc8514033b535125485177f82"

# %%
# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
datos = sp.search(q='genre:"classical" year:2025', type='track', limit=50, offset=0)

# %%
datos.keys()
# Out:
# dict_keys(['tracks'])

# %%
datos['tracks']['items']
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#      'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#      'id': '5aIqB5nVVvmFsvSdExz408',
#      'name': 'Johann Sebastian Bach',
#      'type': 'artist',
#      'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#      'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#      'id': '6I1da3L2KdzSLQvRaSf5RX',
#      'name': 'Günther Ramin',
#      'type': 'artist',
#      'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3wS0kfXAr8Od0mHyINeBSF'},
#    'href': 'https://api.spotify.com/v1/albums/3wS0kfXAr8Od0mHyINeBSF',
#    'id': '3wS0kfXAr8Od0mHyINeBSF',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736c91f6e4615648973645657d'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026c91f6e4615648973645657d'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516c91f6e4615648973645657d'}],
#    'is_playable': True,
#    'name': 'St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)',
#    'release_date': '2025-04-11',
#    'release_date_precision': 'day',
#    'total_tracks': 55,
#    'type': 'album',
#    'uri': 'spotify:album:3wS0kfXAr8Od0mHyINeBSF'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#     'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#     'id': '5aIqB5nVVvmFsvSdExz408',
#     'name': 'Johann Sebastian Bach',
#     'type': 'artist',
#     'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6oDsuTFFaPV9bcQOdojrNc'},
#     'href': 'https://api.spotify.com/v1/artists/6oDsuTFFaPV9bcQOdojrNc',
#     'id': '6oDsuTFFaPV9bcQOdojrNc',
#     'name': 'Siegfried Schulze',
#     'type': 'artist',
#     'uri': 'spotify:artist:6oDsuTFFaPV9bcQOdojrNc'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2c1u0gQqvggX26sHND2QYB'},
#     'href': 'https://api.spotify.com/v1/artists/2c1u0gQqvggX26sHND2QYB',
#     'id': '2c1u0gQqvggX26sHND2QYB',
#     'name': 'Gewandhaus Orchester Leipzig',
#     'type': 'artist',
#     'uri': 'spotify:artist:2c1u0gQqvggX26sHND2QYB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#     'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#     'id': '6I1da3L2KdzSLQvRaSf5RX',
#     'name': 'Günther Ramin',
#     'type': 'artist',
#     'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 133641,
#   'explicit': False,
#   'external_ids': {'isrc': 'USB8U2402152'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5dMfUch1qNeL3kryiUMcLk'},
#   'href': 'https://api.spotify.com/v1/tracks/5dMfUch1qNeL3kryiUMcLk',
#   'id': '5dMfUch1qNeL3kryiUMcLk',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'St. Matthew Passion, BWV 244, Pt. 2: LXIV. Am Abend da es kühle war,',
#   'popularity': 0,
#   'preview_url': None,
#   'track_number': 52,
#   'type': 'track',
#   'uri': 'spotify:track:5dMfUch1qNeL3kryiUMcLk'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#      'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#      'id': '5aIqB5nVVvmFsvSdExz408',
#      'name': 'Johann Sebastian Bach',
#      'type': 'artist',
#      'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#      'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#      'id': '6I1da3L2KdzSLQvRaSf5RX',
#      'name': 'Günther Ramin',
#      'type': 'artist',
#      'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3wS0kfXAr8Od0mHyINeBSF'},
#    'href': 'https://api.spotify.com/v1/albums/3wS0kfXAr8Od0mHyINeBSF',
#    'id': '3wS0kfXAr8Od0mHyINeBSF',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736c91f6e4615648973645657d'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026c91f6e4615648973645657d'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516c91f6e4615648973645657d'}],
#    'is_playable': True,
#    'name': 'St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)',
#    'release_date': '2025-04-11',
#    'release_date_precision': 'day',
#    'total_tracks': 55,
#    'type': 'album',
#    'uri': 'spotify:album:3wS0kfXAr8Od0mHyINeBSF'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#     'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#     'id': '5aIqB5nVVvmFsvSdExz408',
#     'name': 'Johann Sebastian Bach',
#     'type': 'artist',
#     'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/76HODsD07qiiAFoxCaMVIz'},
#     'href': 'https://api.spotify.com/v1/artists/76HODsD07qiiAFoxCaMVIz',
#     'id': '76HODsD07qiiAFoxCaMVIz',
#     'name': 'Thomanerchor Leipzig',
#     'type': 'artist',
#     'uri': 'spotify:artist:76HODsD07qiiAFoxCaMVIz'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2c1u0gQqvggX26sHND2QYB'},
#     'href': 'https://api.spotify.com/v1/artists/2c1u0gQqvggX26sHND2QYB',
#     'id': '2c1u0gQqvggX26sHND2QYB',
#     'name': 'Gewandhaus Orchester Leipzig',
#     'type': 'artist',
#     'uri': 'spotify:artist:2c1u0gQqvggX26sHND2QYB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#     'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#     'id': '6I1da3L2KdzSLQvRaSf5RX',
#     'name': 'Günther Ramin',
#     'type': 'artist',
#     'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 399187,
#   'explicit': False,
#   'external_ids': {'isrc': 'USB8U2402155'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/008imTK8eW5eTwyowSiHjB'},
#   'href': 'https://api.spotify.com/v1/tracks/008imTK8eW5eTwyowSiHjB',
#   'id': '008imTK8eW5eTwyowSiHjB',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'St. Matthew Passion, BWV 244, Pt. 2: LXVIII. Wir setzen uns mit Tränen nieder',
#   'popularity': 0,
#   'preview_url': None,
#   'track_number': 55,
#   'type': 'track',
#   'uri': 'spotify:track:008imTK8eW5eTwyowSiHjB'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#      'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#      'id': '5aIqB5nVVvmFsvSdExz408',
#      'name': 'Johann Sebastian Bach',
#      'type': 'artist',
#      'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#      'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#      'id': '6I1da3L2KdzSLQvRaSf5RX',
#      'name': 'Günther Ramin',
#      'type': 'artist',
#      'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3wS0kfXAr8Od0mHyINeBSF'},
#    'href': 'https://api.spotify.com/v1/albums/3wS0kfXAr8Od0mHyINeBSF',
#    'id': '3wS0kfXAr8Od0mHyINeBSF',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736c91f6e4615648973645657d'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026c91f6e4615648973645657d'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516c91f6e4615648973645657d'}],
#    'is_playable': True,
#    'name': 'St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)',
#    'release_date': '2025-04-11',
#    'release_date_precision': 'day',
#    'total_tracks': 55,
#    'type': 'album',
#    'uri': 'spotify:album:3wS0kfXAr8Od0mHyINeBSF'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#     'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#     'id': '5aIqB5nVVvmFsvSdExz408',
#     'name': 'Johann Sebastian Bach',
#     'type': 'artist',
#     'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0vMvpluxh2qy1Q4GUsHWNC'},
#     'href': 'https://api.spotify.com/v1/artists/0vMvpluxh2qy1Q4GUsHWNC',
#     'id': '0vMvpluxh2qy1Q4GUsHWNC',
#     'name': 'Friedel Beckmann',
#     'type': 'artist',
#     'uri': 'spotify:artist:0vMvpluxh2qy1Q4GUsHWNC'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2c1u0gQqvggX26sHND2QYB'},
#     'href': 'https://api.spotify.com/v1/artists/2c1u0gQqvggX26sHND2QYB',
#     'id': '2c1u0gQqvggX26sHND2QYB',
#     'name': 'Gewandhaus Orchester Leipzig',
#     'type': 'artist',
#     'uri': 'spotify:artist:2c1u0gQqvggX26sHND2QYB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#     'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#     'id': '6I1da3L2KdzSLQvRaSf5RX',
#     'name': 'Günther Ramin',
#     'type': 'artist',
#     'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 121375,
#   'explicit': False,
#   'external_ids': {'isrc': 'USB8U2402148'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0sC3gmVRvpo0lVvDZOCHz3'},
#   'href': 'https://api.spotify.com/v1/tracks/0sC3gmVRvpo0lVvDZOCHz3',
#   'id': '0sC3gmVRvpo0lVvDZOCHz3',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'St. Matthew Passion, BWV 244, Pt. 2: LIX. Ach, Golgatha, unselges Golgatha!',
#   'popularity': 0,
#   'preview_url': None,
#   'track_number': 48,
#   'type': 'track',
#   'uri': 'spotify:track:0sC3gmVRvpo0lVvDZOCHz3'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#      'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#      'id': '5aIqB5nVVvmFsvSdExz408',
#      'name': 'Johann Sebastian Bach',
#      'type': 'artist',
#      'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#      'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#      'id': '6I1da3L2KdzSLQvRaSf5RX',
#      'name': 'Günther Ramin',
#      'type': 'artist',
#      'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3wS0kfXAr8Od0mHyINeBSF'},
#    'href': 'https://api.spotify.com/v1/albums/3wS0kfXAr8Od0mHyINeBSF',
#    'id': '3wS0kfXAr8Od0mHyINeBSF',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736c91f6e4615648973645657d'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026c91f6e4615648973645657d'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516c91f6e4615648973645657d'}],
#    'is_playable': True,
#    'name': 'St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)',
#    'release_date': '2025-04-11',
#    'release_date_precision': 'day',
#    'total_tracks': 55,
#    'type': 'album',
#    'uri': 'spotify:album:3wS0kfXAr8Od0mHyINeBSF'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#     'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#     'id': '5aIqB5nVVvmFsvSdExz408',
#     'name': 'Johann Sebastian Bach',
#     'type': 'artist',
#     'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2sVr8Y8WfEQpWF4iwA0TTP'},
#     'href': 'https://api.spotify.com/v1/artists/2sVr8Y8WfEQpWF4iwA0TTP',
#     'id': '2sVr8Y8WfEQpWF4iwA0TTP',
#     'name': 'Karl Erb',
#     'type': 'artist',
#     'uri': 'spotify:artist:2sVr8Y8WfEQpWF4iwA0TTP'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2c1u0gQqvggX26sHND2QYB'},
#     'href': 'https://api.spotify.com/v1/artists/2c1u0gQqvggX26sHND2QYB',
#     'id': '2c1u0gQqvggX26sHND2QYB',
#     'name': 'Gewandhaus Orchester Leipzig',
#     'type': 'artist',
#     'uri': 'spotify:artist:2c1u0gQqvggX26sHND2QYB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#     'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#     'id': '6I1da3L2KdzSLQvRaSf5RX',
#     'name': 'Günther Ramin',
#     'type': 'artist',
#     'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0S14kz0JUyCviuCJQT00v0'},
#     'href': 'https://api.spotify.com/v1/artists/0S14kz0JUyCviuCJQT00v0',
#     'id': '0S14kz0JUyCviuCJQT00v0',
#     'name': 'Hans Heintze',
#     'type': 'artist',
#     'uri': 'spotify:artist:0S14kz0JUyCviuCJQT00v0'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/76HODsD07qiiAFoxCaMVIz'},
#     'href': 'https://api.spotify.com/v1/artists/76HODsD07qiiAFoxCaMVIz',
#     'id': '76HODsD07qiiAFoxCaMVIz',
#     'name': 'Thomanerchor Leipzig',
#     'type': 'artist',
#     'uri': 'spotify:artist:76HODsD07qiiAFoxCaMVIz'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 144657,
#   'explicit': False,
#   'external_ids': {'isrc': 'USB8U2402153'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1HckR6v2TW5mF6Pwj4tvYg'},
#   'href': 'https://api.spotify.com/v1/tracks/1HckR6v2TW5mF6Pwj4tvYg',
#   'id': '1HckR6v2TW5mF6Pwj4tvYg',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'St. Matthew Passion, BWV 244, Pt. 2: LXVI. Und Joseph nahm den Leib',
#   'popularity': 0,
#   'preview_url': None,
#   'track_number': 53,
#   'type': 'track',
#   'uri': 'spotify:track:1HckR6v2TW5mF6Pwj4tvYg'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#      'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#      'id': '5aIqB5nVVvmFsvSdExz408',
#      'name': 'Johann Sebastian Bach',
#      'type': 'artist',
#      'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#      'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#      'id': '6I1da3L2KdzSLQvRaSf5RX',
#      'name': 'Günther Ramin',
#      'type': 'artist',
#      'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3wS0kfXAr8Od0mHyINeBSF'},
#    'href': 'https://api.spotify.com/v1/albums/3wS0kfXAr8Od0mHyINeBSF',
#    'id': '3wS0kfXAr8Od0mHyINeBSF',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736c91f6e4615648973645657d'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026c91f6e4615648973645657d'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516c91f6e4615648973645657d'}],
#    'is_playable': True,
#    'name': 'St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)',
#    'release_date': '2025-04-11',
#    'release_date_precision': 'day',
#    'total_tracks': 55,
#    'type': 'album',
#    'uri': 'spotify:album:3wS0kfXAr8Od0mHyINeBSF'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#     'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#     'id': '5aIqB5nVVvmFsvSdExz408',
#     'name': 'Johann Sebastian Bach',
#     'type': 'artist',
#     'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0S14kz0JUyCviuCJQT00v0'},
#     'href': 'https://api.spotify.com/v1/artists/0S14kz0JUyCviuCJQT00v0',
#     'id': '0S14kz0JUyCviuCJQT00v0',
#     'name': 'Hans Heintze',
#     'type': 'artist',
#     'uri': 'spotify:artist:0S14kz0JUyCviuCJQT00v0'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2c1u0gQqvggX26sHND2QYB'},
#     'href': 'https://api.spotify.com/v1/artists/2c1u0gQqvggX26sHND2QYB',
#     'id': '2c1u0gQqvggX26sHND2QYB',
#     'name': 'Gewandhaus Orchester Leipzig',
#     'type': 'artist',
#     'uri': 'spotify:artist:2c1u0gQqvggX26sHND2QYB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/76HODsD07qiiAFoxCaMVIz'},
#     'href': 'https://api.spotify.com/v1/artists/76HODsD07qiiAFoxCaMVIz',
#     'id': '76HODsD07qiiAFoxCaMVIz',
#     'name': 'Thomanerchor Leipzig',
#     'type': 'artist',
#     'uri': 'spotify:artist:76HODsD07qiiAFoxCaMVIz'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2sVr8Y8WfEQpWF4iwA0TTP'},
#     'href': 'https://api.spotify.com/v1/artists/2sVr8Y8WfEQpWF4iwA0TTP',
#     'id': '2sVr8Y8WfEQpWF4iwA0TTP',
#     'name': 'Karl Erb',
#     'type': 'artist',
#     'uri': 'spotify:artist:2sVr8Y8WfEQpWF4iwA0TTP'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4XlGvVrH9SVLMA8yra062d'},
#     'href': 'https://api.spotify.com/v1/artists/4XlGvVrH9SVLMA8yra062d',
#     'id': '4XlGvVrH9SVLMA8yra062d',
#     'name': 'Tiana Lemnitz',
#     'type': 'artist',
#     'uri': 'spotify:artist:4XlGvVrH9SVLMA8yra062d'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0vMvpluxh2qy1Q4GUsHWNC'},
#     'href': 'https://api.spotify.com/v1/artists/0vMvpluxh2qy1Q4GUsHWNC',
#     'id': '0vMvpluxh2qy1Q4GUsHWNC',
#     'name': 'Friedel Beckmann',
#     'type': 'artist',
#     'uri': 'spotify:artist:0vMvpluxh2qy1Q4GUsHWNC'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6oDsuTFFaPV9bcQOdojrNc'},
#     'href': 'https://api.spotify.com/v1/artists/6oDsuTFFaPV9bcQOdojrNc',
#     'id': '6oDsuTFFaPV9bcQOdojrNc',
#     'name': 'Siegfried Schulze',
#     'type': 'artist',
#     'uri': 'spotify:artist:6oDsuTFFaPV9bcQOdojrNc'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#     'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#     'id': '6I1da3L2KdzSLQvRaSf5RX',
#     'name': 'Günther Ramin',
#     'type': 'artist',
#     'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 142426,
#   'explicit': False,
#   'external_ids': {'isrc': 'USB8U2402154'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/37ZksFcadOo5cfovo9M94n'},
#   'href': 'https://api.spotify.com/v1/tracks/37ZksFcadOo5cfovo9M94n',
#   'id': '37ZksFcadOo5cfovo9M94n',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'St. Matthew Passion, BWV 244, Pt. 2: LXVII. Nun ist der Herr zur Ruh gebracht',
#   'popularity': 0,
#   'preview_url': None,
#   'track_number': 54,
#   'type': 'track',
#   'uri': 'spotify:track:37ZksFcadOo5cfovo9M94n'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#      'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#      'id': '5aIqB5nVVvmFsvSdExz408',
#      'name': 'Johann Sebastian Bach',
#      'type': 'artist',
#      'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#      'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#      'id': '6I1da3L2KdzSLQvRaSf5RX',
#      'name': 'Günther Ramin',
#      'type': 'artist',
#      'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3wS0kfXAr8Od0mHyINeBSF'},
#    'href': 'https://api.spotify.com/v1/albums/3wS0kfXAr8Od0mHyINeBSF',
#    'id': '3wS0kfXAr8Od0mHyINeBSF',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736c91f6e4615648973645657d'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026c91f6e4615648973645657d'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516c91f6e4615648973645657d'}],
#    'is_playable': True,
#    'name': 'St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)',
#    'release_date': '2025-04-11',
#    'release_date_precision': 'day',
#    'total_tracks': 55,
#    'type': 'album',
#    'uri': 'spotify:album:3wS0kfXAr8Od0mHyINeBSF'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#     'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#     'id': '5aIqB5nVVvmFsvSdExz408',
#     'name': 'Johann Sebastian Bach',
#     'type': 'artist',
#     'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2sVr8Y8WfEQpWF4iwA0TTP'},
#     'href': 'https://api.spotify.com/v1/artists/2sVr8Y8WfEQpWF4iwA0TTP',
#     'id': '2sVr8Y8WfEQpWF4iwA0TTP',
#     'name': 'Karl Erb',
#     'type': 'artist',
#     'uri': 'spotify:artist:2sVr8Y8WfEQpWF4iwA0TTP'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2c1u0gQqvggX26sHND2QYB'},
#     'href': 'https://api.spotify.com/v1/artists/2c1u0gQqvggX26sHND2QYB',
#     'id': '2c1u0gQqvggX26sHND2QYB',
#     'name': 'Gewandhaus Orchester Leipzig',
#     'type': 'artist',
#     'uri': 'spotify:artist:2c1u0gQqvggX26sHND2QYB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#     'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#     'id': '6I1da3L2KdzSLQvRaSf5RX',
#     'name': 'Günther Ramin',
#     'type': 'artist',
#     'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0S14kz0JUyCviuCJQT00v0'},
#     'href': 'https://api.spotify.com/v1/artists/0S14kz0JUyCviuCJQT00v0',
#     'id': '0S14kz0JUyCviuCJQT00v0',
#     'name': 'Hans Heintze',
#     'type': 'artist',
#     'uri': 'spotify:artist:0S14kz0JUyCviuCJQT00v0'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7DT56I7IQNtvEsjpIBt10j'},
#     'href': 'https://api.spotify.com/v1/artists/7DT56I7IQNtvEsjpIBt10j',
#     'id': '7DT56I7IQNtvEsjpIBt10j',
#     'name': 'Gerhard Huesch',
#     'type': 'artist',
#     'uri': 'spotify:artist:7DT56I7IQNtvEsjpIBt10j'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 85587,
#   'explicit': False,
#   'external_ids': {'isrc': 'USB8U2402128'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/78kF0b6otk7KULwJRzdvVx'},
#   'href': 'https://api.spotify.com/v1/tracks/78kF0b6otk7KULwJRzdvVx',
#   'id': '78kF0b6otk7KULwJRzdvVx',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'St. Matthew Passion, BWV 244, Pt. 1: XXVIII. Zu der Stund sprach Jesus zu den Scharen:',
#   'popularity': 1,
#   'preview_url': None,
#   'track_number': 28,
#   'type': 'track',
#   'uri': 'spotify:track:78kF0b6otk7KULwJRzdvVx'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0dFtVIepmvSVnZ1G3NxY6g'},
#      'href': 'https://api.spotify.com/v1/artists/0dFtVIepmvSVnZ1G3NxY6g',
#      'id': '0dFtVIepmvSVnZ1G3NxY6g',
#      'name': 'Dominick Argento',
#      'type': 'artist',
#      'uri': 'spotify:artist:0dFtVIepmvSVnZ1G3NxY6g'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3yH92YtEx8XDzrfDuuKTPv'},
#      'href': 'https://api.spotify.com/v1/artists/3yH92YtEx8XDzrfDuuKTPv',
#      'id': '3yH92YtEx8XDzrfDuuKTPv',
#      'name': 'Adriana Zabala',
#      'type': 'artist',
#      'uri': 'spotify:artist:3yH92YtEx8XDzrfDuuKTPv'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0K8o8LGsaS3bM7BLgYm53Q'},
#      'href': 'https://api.spotify.com/v1/artists/0K8o8LGsaS3bM7BLgYm53Q',
#      'id': '0K8o8LGsaS3bM7BLgYm53Q',
#      'name': 'Jesse Blumberg',
#      'type': 'artist',
#      'uri': 'spotify:artist:0K8o8LGsaS3bM7BLgYm53Q'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4DfsfxqyG6NBYxSrhKLuXp'},
#      'href': 'https://api.spotify.com/v1/artists/4DfsfxqyG6NBYxSrhKLuXp',
#      'id': '4DfsfxqyG6NBYxSrhKLuXp',
#      'name': 'Martin Katz',
#      'type': 'artist',
#      'uri': 'spotify:artist:4DfsfxqyG6NBYxSrhKLuXp'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1itEAUi2eZbJ871cvBEbSO'},
#      'href': 'https://api.spotify.com/v1/artists/1itEAUi2eZbJ871cvBEbSO',
#      'id': '1itEAUi2eZbJ871cvBEbSO',
#      'name': 'J.J. Penna',
#      'type': 'artist',
#      'uri': 'spotify:artist:1itEAUi2eZbJ871cvBEbSO'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2LFY5qF1PxmgKkdmg8ZBVu'},
#    'href': 'https://api.spotify.com/v1/albums/2LFY5qF1PxmgKkdmg8ZBVu',
#    'id': '2LFY5qF1PxmgKkdmg8ZBVu',
# ...
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 125239,
#   'explicit': False,
#   'external_ids': {'isrc': 'USCRS2499115'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/626RDhPmfdx3QVTqeJ2nof'},
#   'href': 'https://api.spotify.com/v1/tracks/626RDhPmfdx3QVTqeJ2nof',
#   'id': '626RDhPmfdx3QVTqeJ2nof',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Cabaret Songs: No. 2, You Are a Love Song',
#   'popularity': 0,
#   'preview_url': None,
#   'track_number': 15,
#   'type': 'track',
#   'uri': 'spotify:track:626RDhPmfdx3QVTqeJ2nof'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0dFtVIepmvSVnZ1G3NxY6g'},
#      'href': 'https://api.spotify.com/v1/artists/0dFtVIepmvSVnZ1G3NxY6g',
#      'id': '0dFtVIepmvSVnZ1G3NxY6g',
#      'name': 'Dominick Argento',
#      'type': 'artist',
#      'uri': 'spotify:artist:0dFtVIepmvSVnZ1G3NxY6g'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3yH92YtEx8XDzrfDuuKTPv'},
#      'href': 'https://api.spotify.com/v1/artists/3yH92YtEx8XDzrfDuuKTPv',
#      'id': '3yH92YtEx8XDzrfDuuKTPv',
#      'name': 'Adriana Zabala',
#      'type': 'artist',
#      'uri': 'spotify:artist:3yH92YtEx8XDzrfDuuKTPv'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0K8o8LGsaS3bM7BLgYm53Q'},
#      'href': 'https://api.spotify.com/v1/artists/0K8o8LGsaS3bM7BLgYm53Q',
#      'id': '0K8o8LGsaS3bM7BLgYm53Q',
#      'name': 'Jesse Blumberg',
#      'type': 'artist',
#      'uri': 'spotify:artist:0K8o8LGsaS3bM7BLgYm53Q'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4DfsfxqyG6NBYxSrhKLuXp'},
#      'href': 'https://api.spotify.com/v1/artists/4DfsfxqyG6NBYxSrhKLuXp',
#      'id': '4DfsfxqyG6NBYxSrhKLuXp',
#      'name': 'Martin Katz',
#      'type': 'artist',
#      'uri': 'spotify:artist:4DfsfxqyG6NBYxSrhKLuXp'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1itEAUi2eZbJ871cvBEbSO'},
#      'href': 'https://api.spotify.com/v1/artists/1itEAUi2eZbJ871cvBEbSO',
#      'id': '1itEAUi2eZbJ871cvBEbSO',
#      'name': 'J.J. Penna',
#      'type': 'artist',
#      'uri': 'spotify:artist:1itEAUi2eZbJ871cvBEbSO'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2LFY5qF1PxmgKkdmg8ZBVu'},
#    'href': 'https://api.spotify.com/v1/albums/2LFY5qF1PxmgKkdmg8ZBVu',
#    'id': '2LFY5qF1PxmgKkdmg8ZBVu',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273fa2cdaaa7f730381761a4877'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02fa2cdaaa7f730381761a4877'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851fa2cdaaa7f730381761a4877'}],
#    'is_playable': True,
#    'name': 'A Few Words About Chekhov',
#    'release_date': '2025-01-03',
#    'release_date_precision': 'day',
#    'total_tracks': 18,
#    'type': 'album',
#    'uri': 'spotify:album:2LFY5qF1PxmgKkdmg8ZBVu'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0dFtVIepmvSVnZ1G3NxY6g'},
#     'href': 'https://api.spotify.com/v1/artists/0dFtVIepmvSVnZ1G3NxY6g',
#     'id': '0dFtVIepmvSVnZ1G3NxY6g',
#     'name': 'Dominick Argento',
#     'type': 'artist',
#     'uri': 'spotify:artist:0dFtVIepmvSVnZ1G3NxY6g'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3yH92YtEx8XDzrfDuuKTPv'},
#     'href': 'https://api.spotify.com/v1/artists/3yH92YtEx8XDzrfDuuKTPv',
#     'id': '3yH92YtEx8XDzrfDuuKTPv',
#     'name': 'Adriana Zabala',
#     'type': 'artist',
#     'uri': 'spotify:artist:3yH92YtEx8XDzrfDuuKTPv'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 216551,
#   'explicit': False,
#   'external_ids': {'isrc': 'USCRS2499103'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7imQDZtXjdgZRKUGqkCk4z'},
#   'href': 'https://api.spotify.com/v1/tracks/7imQDZtXjdgZRKUGqkCk4z',
#   'id': '7imQDZtXjdgZRKUGqkCk4z',
#   'is_local': False,
#   'is_playable': True,
#   'name': '3 Meditations: No. 3, Deep Is the Heart of the Lake',
#   'popularity': 0,
#   'preview_url': None,
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:7imQDZtXjdgZRKUGqkCk4z'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0dFtVIepmvSVnZ1G3NxY6g'},
#      'href': 'https://api.spotify.com/v1/artists/0dFtVIepmvSVnZ1G3NxY6g',
#      'id': '0dFtVIepmvSVnZ1G3NxY6g',
#      'name': 'Dominick Argento',
#      'type': 'artist',
#      'uri': 'spotify:artist:0dFtVIepmvSVnZ1G3NxY6g'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3yH92YtEx8XDzrfDuuKTPv'},
#      'href': 'https://api.spotify.com/v1/artists/3yH92YtEx8XDzrfDuuKTPv',
#      'id': '3yH92YtEx8XDzrfDuuKTPv',
#      'name': 'Adriana Zabala',
#      'type': 'artist',
#      'uri': 'spotify:artist:3yH92YtEx8XDzrfDuuKTPv'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0K8o8LGsaS3bM7BLgYm53Q'},
#      'href': 'https://api.spotify.com/v1/artists/0K8o8LGsaS3bM7BLgYm53Q',
#      'id': '0K8o8LGsaS3bM7BLgYm53Q',
#      'name': 'Jesse Blumberg',
#      'type': 'artist',
#      'uri': 'spotify:artist:0K8o8LGsaS3bM7BLgYm53Q'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4DfsfxqyG6NBYxSrhKLuXp'},
#      'href': 'https://api.spotify.com/v1/artists/4DfsfxqyG6NBYxSrhKLuXp',
#      'id': '4DfsfxqyG6NBYxSrhKLuXp',
#      'name': 'Martin Katz',
#      'type': 'artist',
#      'uri': 'spotify:artist:4DfsfxqyG6NBYxSrhKLuXp'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1itEAUi2eZbJ871cvBEbSO'},
#      'href': 'https://api.spotify.com/v1/artists/1itEAUi2eZbJ871cvBEbSO',
#      'id': '1itEAUi2eZbJ871cvBEbSO',
#      'name': 'J.J. Penna',
#      'type': 'artist',
#      'uri': 'spotify:artist:1itEAUi2eZbJ871cvBEbSO'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2LFY5qF1PxmgKkdmg8ZBVu'},
#    'href': 'https://api.spotify.com/v1/albums/2LFY5qF1PxmgKkdmg8ZBVu',
#    'id': '2LFY5qF1PxmgKkdmg8ZBVu',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273fa2cdaaa7f730381761a4877'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02fa2cdaaa7f730381761a4877'},
#     {'height': 64,
#      'width': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851fa2cdaaa7f730381761a4877'}],
#    'is_playable': True,
#    'name': 'A Few Words About Chekhov',
#    'release_date': '2025-01-03',
#    'release_date_precision': 'day',
#    'total_tracks': 18,
#    'type': 'album',
#    'uri': 'spotify:album:2LFY5qF1PxmgKkdmg8ZBVu'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0dFtVIepmvSVnZ1G3NxY6g'},
#     'href': 'https://api.spotify.com/v1/artists/0dFtVIepmvSVnZ1G3NxY6g',
#     'id': '0dFtVIepmvSVnZ1G3NxY6g',
#     'name': 'Dominick Argento',
#     'type': 'artist',
#     'uri': 'spotify:artist:0dFtVIepmvSVnZ1G3NxY6g'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0K8o8LGsaS3bM7BLgYm53Q'},
#     'href': 'https://api.spotify.com/v1/artists/0K8o8LGsaS3bM7BLgYm53Q',
#     'id': '0K8o8LGsaS3bM7BLgYm53Q',
#     'name': 'Jesse Blumberg',
#     'type': 'artist',
#     'uri': 'spotify:artist:0K8o8LGsaS3bM7BLgYm53Q'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4DfsfxqyG6NBYxSrhKLuXp'},
#     'href': 'https://api.spotify.com/v1/artists/4DfsfxqyG6NBYxSrhKLuXp',
#     'id': '4DfsfxqyG6NBYxSrhKLuXp',
#     'name': 'Martin Katz',
#     'type': 'artist',
#     'uri': 'spotify:artist:4DfsfxqyG6NBYxSrhKLuXp'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'disc_number': 1,
#   'duration_ms': 235591,
#   'explicit': False,
#   'external_ids': {'isrc': 'USCRS2499112'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1f9w3EssBXGnF2O3TDUr5y'},
#   'href': 'https://api.spotify.com/v1/tracks/1f9w3EssBXGnF2O3TDUr5y',
#   'id': '1f9w3EssBXGnF2O3TDUr5y',
#   'is_local': False,
#   'is_playable': True,
#   'name': '3 Sonnets of Petrarch: No. 2, Sonnet No. 164',
#   'popularity': 0,
#   'preview_url': None,
#   'track_number': 12,
#   'type': 'track',
#   'uri': 'spotify:track:1f9w3EssBXGnF2O3TDUr5y'}]

# %%
datos['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#     'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#     'id': '5aIqB5nVVvmFsvSdExz408',
#     'name': 'Johann Sebastian Bach',
#     'type': 'artist',
#     'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#     'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#     'id': '6I1da3L2KdzSLQvRaSf5RX',
#     'name': 'Günther Ramin',
#     'type': 'artist',
#     'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3wS0kfXAr8Od0mHyINeBSF'},
#   'href': 'https://api.spotify.com/v1/albums/3wS0kfXAr8Od0mHyINeBSF',
#   'id': '3wS0kfXAr8Od0mHyINeBSF',
#   'images': [{'height': 640,
#     'width': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2736c91f6e4615648973645657d'},
#    {'height': 300,
#     'width': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e026c91f6e4615648973645657d'},
#    {'height': 64,
#     'width': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048516c91f6e4615648973645657d'}],
#   'is_playable': True,
#   'name': 'St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)',
#   'release_date': '2025-04-11',
#   'release_date_precision': 'day',
#   'total_tracks': 55,
#   'type': 'album',
#   'uri': 'spotify:album:3wS0kfXAr8Od0mHyINeBSF'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#    'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#    'id': '5aIqB5nVVvmFsvSdExz408',
#    'name': 'Johann Sebastian Bach',
#    'type': 'artist',
#    'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6oDsuTFFaPV9bcQOdojrNc'},
#    'href': 'https://api.spotify.com/v1/artists/6oDsuTFFaPV9bcQOdojrNc',
#    'id': '6oDsuTFFaPV9bcQOdojrNc',
#    'name': 'Siegfried Schulze',
#    'type': 'artist',
#    'uri': 'spotify:artist:6oDsuTFFaPV9bcQOdojrNc'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2c1u0gQqvggX26sHND2QYB'},
#    'href': 'https://api.spotify.com/v1/artists/2c1u0gQqvggX26sHND2QYB',
#    'id': '2c1u0gQqvggX26sHND2QYB',
#    'name': 'Gewandhaus Orchester Leipzig',
#    'type': 'artist',
#    'uri': 'spotify:artist:2c1u0gQqvggX26sHND2QYB'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#    'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#    'id': '6I1da3L2KdzSLQvRaSf5RX',
#    'name': 'Günther Ramin',
#    'type': 'artist',
#    'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'PR',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 133641,
#  'explicit': False,
#  'external_ids': {'isrc': 'USB8U2402152'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/5dMfUch1qNeL3kryiUMcLk'},
#  'href': 'https://api.spotify.com/v1/tracks/5dMfUch1qNeL3kryiUMcLk',
#  'id': '5dMfUch1qNeL3kryiUMcLk',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'St. Matthew Passion, BWV 244, Pt. 2: LXIV. Am Abend da es kühle war,',
#  'popularity': 0,
#  'preview_url': None,
#  'track_number': 52,
#  'type': 'track',
#  'uri': 'spotify:track:5dMfUch1qNeL3kryiUMcLk'}

# %%
print(datos['tracks']['items'][1]['name'])
print(datos['tracks']['items'][1]['type'])
# Out:
# St. Matthew Passion, BWV 244, Pt. 2: LXVIII. Wir setzen uns mit Tränen nieder
# track

# %%
datos['tracks']['items'][1].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
datos['tracks']['items'][1]['album']
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#    'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#    'id': '5aIqB5nVVvmFsvSdExz408',
#    'name': 'Johann Sebastian Bach',
#    'type': 'artist',
#    'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#    'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#    'id': '6I1da3L2KdzSLQvRaSf5RX',
#    'name': 'Günther Ramin',
#    'type': 'artist',
#    'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'PR',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/3wS0kfXAr8Od0mHyINeBSF'},
#  'href': 'https://api.spotify.com/v1/albums/3wS0kfXAr8Od0mHyINeBSF',
#  'id': '3wS0kfXAr8Od0mHyINeBSF',
#  'images': [{'height': 640,
#    'width': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b2736c91f6e4615648973645657d'},
#   {'height': 300,
#    'width': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e026c91f6e4615648973645657d'},
#   {'height': 64,
#    'width': 64,
#    'url': 'https://i.scdn.co/image/ab67616d000048516c91f6e4615648973645657d'}],
#  'is_playable': True,
#  'name': 'St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)',
#  'release_date': '2025-04-11',
#  'release_date_precision': 'day',
#  'total_tracks': 55,
#  'type': 'album',
#  'uri': 'spotify:album:3wS0kfXAr8Od0mHyINeBSF'}

# %%
datos['tracks']['items'][1]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#   'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#   'id': '5aIqB5nVVvmFsvSdExz408',
#   'name': 'Johann Sebastian Bach',
#   'type': 'artist',
#   'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/76HODsD07qiiAFoxCaMVIz'},
#   'href': 'https://api.spotify.com/v1/artists/76HODsD07qiiAFoxCaMVIz',
#   'id': '76HODsD07qiiAFoxCaMVIz',
#   'name': 'Thomanerchor Leipzig',
#   'type': 'artist',
#   'uri': 'spotify:artist:76HODsD07qiiAFoxCaMVIz'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2c1u0gQqvggX26sHND2QYB'},
#   'href': 'https://api.spotify.com/v1/artists/2c1u0gQqvggX26sHND2QYB',
#   'id': '2c1u0gQqvggX26sHND2QYB',
#   'name': 'Gewandhaus Orchester Leipzig',
#   'type': 'artist',
#   'uri': 'spotify:artist:2c1u0gQqvggX26sHND2QYB'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#   'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#   'id': '6I1da3L2KdzSLQvRaSf5RX',
#   'name': 'Günther Ramin',
#   'type': 'artist',
#   'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'}]

# %%
len(datos['tracks']['items'][1]['artists'])
# Out:
# 4

# %%
datos['tracks']['items'][1]['artists'][0]['name']
# Out:
# 'Johann Sebastian Bach'

# %%
datos['tracks']['items'][1]['album']['name'] #nombre del album
# Out:
# 'St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)'

# %%
datos['tracks']['items'][1]['album']['release_date'] #fecha de lanzamiento
# Out:
# '2025-04-11'

# %%
#elementos necesarias
print(datos['tracks']['items'][1]['artists'][0]['name']) #nombre artista
print(datos['tracks']['items'][1]['album']['name']) #nombre del album
print(datos['tracks']['items'][1]['album']['release_date']) #fecha de lanzamiento
print(datos['tracks']['items'][1]['type']) #tipo
# Out:
# Johann Sebastian Bach
# St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)
# 2025-04-11
# track

# %%
#crear función

#genre = 'classical'
#year = '2025' 
def llamada(self, genre, year):
    self.genre = genre
    self.year = year
    for i in datos: #i cambiar item
        datos = sp.search(q='genre: {genre} year: {year}', type='track', limit=50, offset=0) #poner format
        print(datos['tracks']['items'][i]['artists'][0]['name']) #nombre artista
        print(datos['tracks']['items'][i]['album']['name']) #nombre del album
        print(datos['tracks']['items'][i]['album']['release_date']) #fecha de lanzamiento
        print(datos['tracks']['items'][i]['type']) #tipo 
    return llamada

# %%
llamada(classical, 2025)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 llamada(classical, 2025)
#
# NameError: name 'classical' is not defined
