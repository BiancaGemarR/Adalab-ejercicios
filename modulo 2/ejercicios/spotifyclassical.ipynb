# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
CLIENT_ID = "fd65ba2c42ec4fa281add322068595c1"
CLIENT_SECRET = "834a625cc8514033b535125485177f82"

# %%
# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
datos = sp.search(q='genre:"classical" year:2025', type='track', limit=50, offset=0)

# %%
datos.keys()
# Out:
# dict_keys(['tracks'])

# %%
datos['tracks']['items']
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#      'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#      'id': '5aIqB5nVVvmFsvSdExz408',
#      'name': 'Johann Sebastian Bach',
#      'type': 'artist',
#      'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#      'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#      'id': '6I1da3L2KdzSLQvRaSf5RX',
#      'name': 'Günther Ramin',
#      'type': 'artist',
#      'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
# ...

# %%
datos['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#     'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#     'id': '5aIqB5nVVvmFsvSdExz408',
#     'name': 'Johann Sebastian Bach',
#     'type': 'artist',
#     'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#     'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#     'id': '6I1da3L2KdzSLQvRaSf5RX',
#     'name': 'Günther Ramin',
#     'type': 'artist',
#     'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
# ...

# %%
print(datos['tracks']['items'][1]['name'])
print(datos['tracks']['items'][1]['type'])
# Out:
# St. Matthew Passion, BWV 244, Pt. 2: LXVI. Und Joseph nahm den Leib
# track

# %%
datos['tracks']['items'][1].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
datos['tracks']['items'][1]['album']
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#    'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#    'id': '5aIqB5nVVvmFsvSdExz408',
#    'name': 'Johann Sebastian Bach',
#    'type': 'artist',
#    'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6I1da3L2KdzSLQvRaSf5RX'},
#    'href': 'https://api.spotify.com/v1/artists/6I1da3L2KdzSLQvRaSf5RX',
#    'id': '6I1da3L2KdzSLQvRaSf5RX',
#    'name': 'Günther Ramin',
#    'type': 'artist',
#    'uri': 'spotify:artist:6I1da3L2KdzSLQvRaSf5RX'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
# ...

# %%
datos['tracks']['items'][1]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aIqB5nVVvmFsvSdExz408'},
#   'href': 'https://api.spotify.com/v1/artists/5aIqB5nVVvmFsvSdExz408',
#   'id': '5aIqB5nVVvmFsvSdExz408',
#   'name': 'Johann Sebastian Bach',
#   'type': 'artist',
#   'uri': 'spotify:artist:5aIqB5nVVvmFsvSdExz408'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2sVr8Y8WfEQpWF4iwA0TTP'},
#   'href': 'https://api.spotify.com/v1/artists/2sVr8Y8WfEQpWF4iwA0TTP',
#   'id': '2sVr8Y8WfEQpWF4iwA0TTP',
#   'name': 'Karl Erb',
#   'type': 'artist',
#   'uri': 'spotify:artist:2sVr8Y8WfEQpWF4iwA0TTP'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2c1u0gQqvggX26sHND2QYB'},
#   'href': 'https://api.spotify.com/v1/artists/2c1u0gQqvggX26sHND2QYB',
#   'id': '2c1u0gQqvggX26sHND2QYB',
#   'name': 'Gewandhaus Orchester Leipzig',
#   'type': 'artist',
#   'uri': 'spotify:artist:2c1u0gQqvggX26sHND2QYB'},
# ...

# %%
len(datos['tracks']['items'][1]['artists'])
# Out:
# 6

# %%
datos['tracks']['items'][1]['artists'][0]['name']
# Out:
# 'Johann Sebastian Bach'

# %%
datos['tracks']['items'][1]['album']['name'] #nombre del album
# Out:
# 'St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)'

# %%
datos['tracks']['items'][1]['album']['release_date'] #fecha de lanzamiento
# Out:
# '2025-04-11'

# %%
#elementos necesarias
print(datos['tracks']['items'][1]['artists'][0]['name']) #nombre artista
print(datos['tracks']['items'][1]['album']['name']) #nombre del album
print(datos['tracks']['items'][1]['album']['release_date']) #fecha de lanzamiento
print(datos['tracks']['items'][1]['type']) #tipo
# Out:
# Johann Sebastian Bach
# St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)
# 2025-04-11
# track

# %%
#crear función

#genre = 'classical'
#year = '2025' 
def llamada(genre, year):
    datos = sp.search(q= f'genre:{genre},year:{year}', type='track', limit=50, offset=0) #poner format
    for item in datos['tracks']['items']: 
        print(item['artists'][0]['name']) #nombre artista
        print(item['album']['name']) #nombre del album
        print(item['album']['release_date']) #fecha de lanzamiento
        print(item['type']) #tipo

# %%
llamada('classical', '2025')

# %%
def llamada(genre, year):
    datos = sp.search(q=f'genre:{genre} year:{year}', type='track', limit=50, offset=0)

    for item in datos['tracks']['items']:
        print(item['artists'][0]['name'])
        print(item['album']['name'])
        print(item['album']['release_date'])
        print(item['type'])

# %%
llamada('classical', '2025')
# Out:
# Johann Sebastian Bach
# St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)
# 2025-04-11
# track
# Johann Sebastian Bach
# St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)
# 2025-04-11
# track
# Johann Sebastian Bach
# St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)
# 2025-04-11
# track
# Johann Sebastian Bach
# St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)
# 2025-04-11
# track
# Johann Sebastian Bach
# St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)
# 2025-04-11
# track
# Dominick Argento
# A Few Words About Chekhov
# 2025-01-03
# track
# George Frideric Handel
# Chorals & Hymns
# 2025-02-07
# track
# Claudio Monteverdi
# Guido Cantelli Spectacular! Live Rarities
# 2025-01-03
# track
# Ottorino Respighi
# ...

# %%
#resultados = []
#def llamada_api(sp):
    #for año in range(2016,2022):
        #for offset in range (0,500,50):
            #datos = sp.search(q=f'genre:"pop" year:{año}', type='track', limit=50, offset= 0)
            #for item in datos:
                #datos['tracks']['items']['artists'][0]['name']
                #datos['tracks']['items']['album']['name']
                #datos['tracks']['items']['album']['release_date']
                #datos['tracks']['items']['type']
                #resultados.append(datos)
    
            #return resultados

# %%
llamada('classical', 2025)
# Out:
# Johann Sebastian Bach
# St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)
# 2025-04-11
# track
# Johann Sebastian Bach
# St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)
# 2025-04-11
# track
# Johann Sebastian Bach
# St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)
# 2025-04-11
# track
# Johann Sebastian Bach
# St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)
# 2025-04-11
# track
# Johann Sebastian Bach
# St. Matthew Passion conducted by Günther Ramin the legendary 1941 Recording HD Mastering (Studio)
# 2025-04-11
# track
# Dominick Argento
# A Few Words About Chekhov
# 2025-01-03
# track
# George Frideric Handel
# Chorals & Hymns
# 2025-02-07
# track
# Claudio Monteverdi
# Guido Cantelli Spectacular! Live Rarities
# 2025-01-03
# track
# Ottorino Respighi
# ...

# %%
datos = sp.search(q= 'genre : classical, year: 2019', type = 'album', limit= 50, offset=0)
print(datos["albums"]["items"][25]["name"])
print(datos["albums"]["items"][25]["artists"][0]["name"])
# Out:
# Grandes Orquestas de Galicia. Feliz 2014.
# Various Artists

# %%
datos["albums"]["items"][25].keys()
# Out:
# {'album_type': 'compilation',
#  'total_tracks': 100,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'MK',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
# ...
